# %% [markdown]
# # CS-141 Homework 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

# %load_ext autoreload
# %autoreload 2
# %autosave 180
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Autosaving every 180 seconds

# %%
# Question 1.3: Implement state prediction step of Kalman filter

# Assume at t=0, pos, vel, and accel = 0
# Calculate state disrtibution for times t = 1,2,...,5

# Time settings
dt = 1 # Assume delta t is 1 second
t_total = 5 # Total time in seconds
t_steps = int(t_total/dt) # Time steps 

# Initialize resting state 
x_0 = np.array([[0],[0]])
cov_0 = ([0, 0],[0, 0])


# Create a state vector for number of time steps t
states = [x_0]
posts = [cov_0]

muh_a = 0 # avg accel
sigma_a = 1 

# State transition 
# Linear matrices A and B
A = np.array([[1, dt], [0, 1]])
B = np.array([[.5*dt**2], [dt]])
R = sigma_a * np.array([[.25, .5],[.5, 1]])
# print(R)

t = 0

for i in range(1, t_steps+1):
    # Random sample for accel using normal dist
    u_t = np.random.normal(muh_a, sigma_a, size=(1,1))
    # State prediction 
    state_new = A @ states[-1] + B @ u_t

    # Posterior 
    post_new = A @ posts[-1] @ A.T + R
    print("\n New posterior \n",post_new)

    # Eigenvalues and eigenvectors of covariance matrix 
    eig_vals, eig_vect = np.linalg.eig(post_new)
    print("\n Eigenvalues \n",eig_vals)
    print("\n Eigenvectors \n",eig_vect)

    lamdax = eig_vals[0]
    lamday = eig_vals[1]

    # Get smallest and largest eigenvectors/values
    max_ind = np.argmax(np.abs(eig_vals)) # USE ABSOLUTE VALUE?
    print("\n Max eig value indice =",max_ind)
    max_EV = eig_vect[max_ind]
    print("\n Max eig vector = ", max_EV)
    if max_ind == 0:
        min_EV = eig_vect[:,1]
        # min_eval = 
    else:
        min_EV = eig_vect[:,0]
    print("\n Min eig vector = ", min_EV)
    # Major and minor axes
    maj_len = 2*np.sqrt(lamdax)
    min_len = 2*np.sqrt(lamday)
    # Angle between x-axis and largest eigenvector
    angle = np.arctan2(max_EV[1], max_EV[0])
    if angle < 0: angle += 2*np.pi
    print("\n Angle between x-axis and largest EV = ", angle)
    chi_sq = 1
    


    # Add state prediction and posterior 
    states.append(state_new)
    posts.append(post_new)

states = np.hstack(states)
posts = np.hstack(posts)

print("\n States from t=0 to t=5 \n",states)
print("\n Posterior over x and x_dot \n",posts)
# Out:
#  New posterior
#  [[0.25 0.5 ]
#  [0.5  1.  ]]
#
#  Eigenvalues
#  [0.   1.25]
#
#  Eigenvectors
#  [[-0.89442719 -0.4472136 ]
#  [ 0.4472136  -0.89442719]]
#
#  Max eig value indice = 1
#
#  Max eig vector =  [ 0.4472136  -0.89442719]
#
#  Min eig vector =  [-0.89442719  0.4472136 ]
#
#  Angle between x-axis and largest EV =  5.176036589385496
#
#  New posterior
#  [[2.5 2. ]
#  [2.  2. ]]
#
#  Eigenvalues
#  [4.26556444 0.23443556]
#
#  Eigenvectors
#  [[ 0.74967818 -0.66180256]
#  [ 0.66180256  0.74967818]]
#
#  Max eig value indice = 0
#
#  Max eig vector =  [ 0.74967818 -0.66180256]
#
#  Min eig vector =  [-0.66180256  0.74967818]
#
#  Angle between x-axis and largest EV =  5.559964641055519
#
#  New posterior
#  [[8.75 4.5 ]
#  [4.5  3.  ]]
#
#  Eigenvalues
#  [11.21500234  0.53499766]
#
#  Eigenvectors
#  [[ 0.87703742 -0.48042207]
#  [ 0.48042207  0.87703742]]
#
#  Max eig value indice = 0
#
#  Max eig vector =  [ 0.87703742 -0.48042207]
#
#  Min eig vector =  [-0.48042207  0.87703742]
#
#  Angle between x-axis and largest EV =  5.782049417647658
#
#  New posterior
#  [[21.  8.]
#  [ 8.  4.]]
#
#  Eigenvalues
#  [24.17261753  0.82738247]
#
#  Eigenvectors
#  [[ 0.92956979 -0.36864618]
#  [ 0.36864618  0.92956979]]
#
#  Max eig value indice = 0
#
#  Max eig vector =  [ 0.92956979 -0.36864618]
#
#  Min eig vector =  [-0.36864618  0.92956979]
#
#  Angle between x-axis and largest EV =  5.905633105440249
#
#  New posterior
#  [[41.25 12.5 ]
#  [12.5   5.  ]]
#
#  Eigenvalues
#  [45.14239369  1.10760631]
#
#  Eigenvectors
#  [[ 0.95478081 -0.29731062]
#  [ 0.29731062  0.95478081]]
#
#  Max eig value indice = 0
#
#  Max eig vector =  [ 0.95478081 -0.29731062]
#
#  Min eig vector =  [-0.29731062  0.95478081]
#
#  Angle between x-axis and largest EV =  5.981310640480868
#
#  States from t=0 to t=5
#  [[ 0.         -0.76651769 -2.03987458 -2.87155507 -3.75504075 -4.7168493 ]
#  [ 0.         -1.53303538 -1.0136784  -0.64968258 -1.11728878 -0.80632831]]
#
#  Posterior over x and x_dot
#  [[ 0.    0.    0.25  0.5   2.5   2.    8.75  4.5  21.    8.   41.25 12.5 ]
#  [ 0.    0.    0.5   1.    2.    2.    4.5   3.    8.    4.   12.5   5.  ]]

# %%
# Question 1.4: Plot the joint posterior for x and xdot for each time value t
# For each posterior, plot the uncertainty ellipse - 1 SD away from mean
